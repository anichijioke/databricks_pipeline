# %%
df = spark.read.table("databricks_cata.bronze.regions")
df.display()

# %%
df = df.drop("_rescued_data")
display(df)

# %%
df.write.format("delta").mode("overwrite").save("abfss://silver@databricksetee.dfs.core.windows.net/regions")

# %%
df = spark.read.format("delta").load("abfss://silver@databricksetee.dfs.core.windows.net/products/")
display(df)

# %%
# %sql
CREATE TABLE IF NOT EXISTS databricks_cata.silver.regions_silver
USING DELTA
LOCATION 'abfss://silver@databricksetee.dfs.core.windows.net/regions/';
